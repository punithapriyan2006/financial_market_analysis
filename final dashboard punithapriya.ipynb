# %%
# !pip install streamlit pyngrok pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 91.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 102.0 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3.12/pathlib.py in __str__(self)
#     440         try:
# --> 441             return self._str
#     442         except AttributeError:
#
# AttributeError: 'PosixPath' object has no attribute '_str'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3.12/pathlib.py in drive(self)
#     554         try:
# --> 555             return self._drv
#     556         except AttributeError:
#
# AttributeError: 'PosixPath' object has no attribute '_drv'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import pandas as pd
data = pd.read_csv("batch 3 dataset-ai financial market realistic synthesis (2).csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_22701/1885307987.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("batch 3 dataset-ai financial market realistic synthesis (2).csv")
#
# ...

# %%
# !streamlit run steamlite_financial.py &>/content/logs.txt &

# %%
from pyngrok import ngrok

# IMPORTANT: Replace 'YOUR_AUTHTOKEN' with your actual ngrok authtoken.
# You can obtain it from your ngrok dashboard: https://dashboard.ngrok.com/get-started/your-authtoken
ngrok.set_auth_token("3BzBxuaBSzzYFEk7pQ47KnASxl2_26i2vdZ7SAC15nGLSua49") # <-- Make sure to replace this with your actual token!

public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://lamont-placentary-modesta.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %%writefile steamlite_financial.py
import pandas as pd
import streamlit as st
import matplotlib.pyplot as plt

st.title("📊 Financial Marketing Dashboard")

uploaded_file = st.file_uploader("Upload your dataset", type=["csv"])

if uploaded_file is not None:
    data = pd.read_csv(uploaded_file)

    st.subheader("Dataset Preview")
    st.write(data.head())

    column = st.selectbox("Select column", data.columns)

    if data[column].dtype == 'object':
        pie_data = data[column].value_counts().head(10)
        fig, ax = plt.subplots()
        ax.pie(pie_data, labels=pie_data.index, autopct='%1.1f%%')
        st.pyplot(fig)
    else:
        st.line_chart(data[column])
else:
    st.warning("Upload a CSV file")
# Out:
# Writing steamlite_financial.py

# %%
# !pip install streamlit pyngrok pandas matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 88.4 MB/s eta 0:00:00
# ...

# %%
# !streamlit run steamlite_financial.py &>/content/logs.txt &

# %%
import pandas as pd
# !pip install pyngrok
from pyngrok import ngrok
import time

# IMPORTANT: Replace 'YOUR_AUTHTOKEN' with your actual ngrok authtoken.
# You can obtain it from your ngrok dashboard: https://dashboard.ngrok.com/get-started/your-authtoken
ngrok.set_auth_token("3BzBxuaBSzzYFEk7pQ47KnASxl2_26i2vdZ7SAC15nGLSua49") # <-- Make sure to replace this with your actual token!

# Ensure no ngrok processes are running locally
ngrok.kill()
time.sleep(1) # Give ngrok processes time to terminate

# Disconnect any previously established tunnels by this pyngrok instance
try:
    # This attempts to disconnect all tunnels managed by pyngrok
    ngrok.disconnect()
    time.sleep(1) # Give it a moment to disconnect
except Exception as e:
    # This can happen if no ngrok process was running, or no tunnels were active.
    print(f"No active tunnels to disconnect, or error during disconnect: {e}")

public_url = ngrok.connect(8501)
print(public_url)
# Out:
# ...
# No active tunnels to disconnect, or error during disconnect: disconnect() missing 1 required positional argument: 'public_url'
# NgrokTunnel: "https://lamont-placentary-modesta.ngrok-free.dev" -> "http://localhost:8501"
